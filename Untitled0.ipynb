# %% [markdown]
# <a href="https://colab.research.google.com/github/67Luka67/my-first-project/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Edit from branch")
# Out:
# Edit from branch
